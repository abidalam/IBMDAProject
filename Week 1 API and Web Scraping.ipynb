# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import datetime
import scipy.stats

# %matplotlib inline
#sets the default autosave frequency in seconds
# %autosave 60 
sns.set_style('dark')
sns.set(font_scale=1.2)

import warnings
warnings.filterwarnings('ignore')

#import feature_engine.missing_data_imputers as mdi
#from feature_engine.outlier_removers import Winsorizer
#from feature_engine import categorical_encoders as ce

pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)
pd.set_option('display.width', 1000)

np.random.seed(0)
np.set_printoptions(suppress=True)
# Out:
# Autosaving every 60 seconds

# %%
df = pd.read_csv("github-job-postings.csv")

# %%
df
# Out:
#    Technology Name  No of Jobs Postings
# 0                C                  187
# 1               C#                   14
# 2              C++                   23
# 3             Java                   91
# 4       JavaScript                   64
# 5           Python                   53
# 6            Scala                   47
# 7           Oracle                    6
# 8       SQL Server                   16
# 9     MySQL Server                    5
# 10      PostgreSQL                   16
# 11         MongoDB                    4

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Univariate Data Exploration

# %%
plt.figure(figsize=(16,9))
plt.title("Number of Jobs @ Github")
sns.barplot(data=df.sort_values(by="No of Jobs Postings", ascending=False),x="Technology Name",y="No of Jobs Postings")
plt.show()

# %%
df2 = pd.read_csv("popular-languages.csv")

# %%
df2
# Out:
#      Language  Average Annual Salary
# 0      Python                 114383
# 1        Java                 101013
# 2           R                  92037
# 3  Javascript                 110981
# 4       Swift                 130801
# 5         C++                 113865
# 6          C#                  88726
# 7         PHP                  84727
# 8         SQL                  84793
# 9          Go                  94082

# %%
plt.figure(figsize=(16,9))
plt.title("Job Salaries")
sns.barplot(data=df2.sort_values(by="Average Annual Salary", ascending=False),x="Language",y="Average Annual Salary")
plt.show()
